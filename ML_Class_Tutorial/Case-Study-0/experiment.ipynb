# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("creditcard_updated.csv")

# %%
data.head()
# Out:
#    Transaction_Time  Transaction_Risk_Score  Merchant_Trustworthiness_Score  \
# 0               0.0               -1.359807                       -0.072781
# 1               0.0                1.191857                        0.266151
# 2               1.0               -1.358354                       -1.340163
# 3               1.0               -0.966272                       -0.185226
# 4               2.0               -1.158233                        0.877737
#
#    Customer_Spending_Behavior_Index  Transaction_Volume_Change  \
# 0                          2.536347                   1.378155
# 1                          0.166480                   0.448154
# 2                          1.773209                   0.379780
# 3                          1.792993                  -0.863291
# 4                          1.548718                   0.403034
#
#    Credit_Utilization_Percentage  Account_Balance_Variation  \
# 0                      -0.338321                   0.462388
# 1                       0.060018                  -0.082361
# 2                      -0.503198                   1.800499
# 3                      -0.010309                   1.247203
# 4                      -0.407193                   0.095921
#
#    Num_Previous_Transactions_24h  Num_Failed_Transaction_Attempts  Card_Type  \
# 0                       0.239599                         0.098698   0.363787
# 1                      -0.078803                         0.085102  -0.255425
# 2                       0.791461                         0.247676  -1.514654
# 3                       0.237609                         0.377436  -1.387024
# 4                       0.592941                        -0.270533   0.817739
#
#    ...  Num_Chargebacks  Avg_Transaction_Amount_30Days  Num_Linked_Accounts  \
# 0  ...        -0.018307                       0.277838            -0.110474
# 1  ...        -0.225775                      -0.638672             0.101288
# 2  ...         0.247998                       0.771679             0.909412
# 3  ...        -0.108300                       0.005274            -0.190321
# 4  ...        -0.009431                       0.798278            -0.137458
#
#    Account_Login_Attempts_24h  Unusual_Purchase_Behavior_Score  \
# 0                    0.066928                         0.128539
# 1                   -0.339846                         0.167170
# 2                   -0.689281                        -0.327642
# 3                   -1.175575                         0.647376
# 4                    0.141267                        -0.206010
#
#    Cashback_Discount_Usage  ATM_Withdrawal_Amount  \
# 0                -0.189115               0.133558
# 1                 0.125895              -0.008983
# 2                -0.139097              -0.055353
# 3                -0.221929               0.062723
# 4                 0.502292               0.219422
#
#    Num_Different_Devices_Used_30Days  Transaction_Amount  Fraud_Label
# 0                          -0.021053              149.62            0
# 1                           0.014724                2.69            0
# 2                          -0.059752              378.66            0
# 3                           0.061458              123.50            0
# 4                           0.215153               69.99            0
#
# [5 rows x 31 columns]

# %%
data.describe()
# Out:
#        Transaction_Time  Transaction_Risk_Score  \
# count     284807.000000            2.848070e+05
# mean       94813.859575            1.168375e-15
# std        47488.145955            1.958696e+00
# min            0.000000           -5.640751e+01
# 25%        54201.500000           -9.203734e-01
# 50%        84692.000000            1.810880e-02
# 75%       139320.500000            1.315642e+00
# max       172792.000000            2.454930e+00
#
#        Merchant_Trustworthiness_Score  Customer_Spending_Behavior_Index  \
# count                    2.848070e+05                      2.848070e+05
# mean                     3.416908e-16                     -1.379537e-15
# std                      1.651309e+00                      1.516255e+00
# min                     -7.271573e+01                     -4.832559e+01
# 25%                     -5.985499e-01                     -8.903648e-01
# 50%                      6.548556e-02                      1.798463e-01
# 75%                      8.037239e-01                      1.027196e+00
# max                      2.205773e+01                      9.382558e+00
#
#        Transaction_Volume_Change  Credit_Utilization_Percentage  \
# count               2.848070e+05                   2.848070e+05
# mean                2.074095e-15                   9.604066e-16
# std                 1.415869e+00                   1.380247e+00
# min                -5.683171e+00                  -1.137433e+02
# 25%                -8.486401e-01                  -6.915971e-01
# 50%                -1.984653e-02                  -5.433583e-02
# 75%                 7.433413e-01                   6.119264e-01
# max                 1.687534e+01                   3.480167e+01
#
#        Account_Balance_Variation  Num_Previous_Transactions_24h  \
# count               2.848070e+05                   2.848070e+05
# mean                1.487313e-15                  -5.556467e-16
# std                 1.332271e+00                   1.237094e+00
# min                -2.616051e+01                  -4.355724e+01
# 25%                -7.682956e-01                  -5.540759e-01
# 50%                -2.741871e-01                   4.010308e-02
# 75%                 3.985649e-01                   5.704361e-01
# max                 7.330163e+01                   1.205895e+02
#
#        Num_Failed_Transaction_Attempts     Card_Type  ...  Num_Chargebacks  \
# count                     2.848070e+05  2.848070e+05  ...     2.848070e+05
# mean                      1.213481e-16 -2.406331e-15  ...     1.654067e-16
# std                       1.194353e+00  1.098632e+00  ...     7.345240e-01
# min                      -7.321672e+01 -1.343407e+01  ...    -3.483038e+01
# 25%                      -2.086297e-01 -6.430976e-01  ...    -2.283949e-01
# 50%                       2.235804e-02 -5.142873e-02  ...    -2.945017e-02
# 75%                       3.273459e-01  5.971390e-01  ...     1.863772e-01
# max                       2.000721e+01  1.559499e+01  ...     2.720284e+01
#
#        Avg_Transaction_Amount_30Days  Num_Linked_Accounts  \
# count                   2.848070e+05         2.848070e+05
# mean                   -3.568593e-16         2.578648e-16
# std                     7.257016e-01         6.244603e-01
# min                    -1.093314e+01        -4.480774e+01
# 25%                    -5.423504e-01        -1.618463e-01
# 50%                     6.781943e-03        -1.119293e-02
# 75%                     5.285536e-01         1.476421e-01
# max                     1.050309e+01         2.252841e+01
#
#        Account_Login_Attempts_24h  Unusual_Purchase_Behavior_Score  \
# count                2.848070e+05                     2.848070e+05
# mean                 4.473266e-15                     5.340915e-16
# std                  6.056471e-01                     5.212781e-01
# min                 -2.836627e+00                    -1.029540e+01
# 25%                 -3.545861e-01                    -3.171451e-01
# 50%                  4.097606e-02                     1.659350e-02
# 75%                  4.395266e-01                     3.507156e-01
# max                  4.584549e+00                     7.519589e+00
#
#        Cashback_Discount_Usage  ATM_Withdrawal_Amount  \
# count             2.848070e+05           2.848070e+05
# mean              1.683437e-15          -3.660091e-16
# std               4.822270e-01           4.036325e-01
# min              -2.604551e+00          -2.256568e+01
# 25%              -3.269839e-01          -7.083953e-02
# 50%              -5.213911e-02           1.342146e-03
# 75%               2.409522e-01           9.104512e-02
# max               3.517346e+00           3.161220e+01
#
#        Num_Different_Devices_Used_30Days  Transaction_Amount    Fraud_Label
# count                       2.848070e+05       284807.000000  284807.000000
# mean                       -1.227390e-16           88.349619       0.001727
# std                         3.300833e-01          250.120109       0.041527
# min                        -1.543008e+01            0.000000       0.000000
# 25%                        -5.295979e-02            5.600000       0.000000
# 50%                         1.124383e-02           22.000000       0.000000
# 75%                         7.827995e-02           77.165000       0.000000
# max                         3.384781e+01        25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
data.dropna(axis=1, inplace=True)
# Out:
# Transaction_Risk_Score  Merchant_Trustworthiness_Score  Customer_Spending_Behavior_Index  Transaction_Volume_Change  Credit_Utilization_Percentage  Account_Balance_Variation  Num_Previous_Transactions_24h  Num_Failed_Transaction_Attempts  Card_Type  Months_Until_Card_Expiry  Transaction_Location_Consistency  Customer_Account_Age  Transaction_Hour  Transaction_Frequency_Per_Day  Previous_Fraud_Activity_Flag  Device_Type_Risk_Score  IP_Address_Mismatch  Merchant_Reputation_Score  Cross_Border_Transaction_Flag  Distance_Between_Transactions  Num_Chargebacks  Avg_Transaction_Amount_30Days  Num_Linked_Accounts  Account_Login_Attempts_24h  Unusual_Purchase_Behavior_Score  Cashback_Discount_Usage  ATM_Withdrawal_Amount  Num_Different_Devices_Used_30Days  Transaction_Amount  Fraud_Label
# False                   False                           False                             False                      False                          False                      False                          False                            False      False                     False                             False                 False             False                          False                         False                   False                False                      False                          False                          False            False                          False                False                       False                            False                    False                  False                              False               False          284807
# Name: count, dtype: int64

# %%
data.drop(["Transaction_Time"], inplace=True, axis=1)

# %%
data.head()
# Out:
#    Transaction_Risk_Score  Merchant_Trustworthiness_Score  \
# 0               -1.359807                       -0.072781
# 1                1.191857                        0.266151
# 2               -1.358354                       -1.340163
# 3               -0.966272                       -0.185226
# 4               -1.158233                        0.877737
#
#    Customer_Spending_Behavior_Index  Transaction_Volume_Change  \
# 0                          2.536347                   1.378155
# 1                          0.166480                   0.448154
# 2                          1.773209                   0.379780
# 3                          1.792993                  -0.863291
# 4                          1.548718                   0.403034
#
#    Credit_Utilization_Percentage  Account_Balance_Variation  \
# 0                      -0.338321                   0.462388
# 1                       0.060018                  -0.082361
# 2                      -0.503198                   1.800499
# 3                      -0.010309                   1.247203
# 4                      -0.407193                   0.095921
#
#    Num_Previous_Transactions_24h  Num_Failed_Transaction_Attempts  Card_Type  \
# 0                       0.239599                         0.098698   0.363787
# 1                      -0.078803                         0.085102  -0.255425
# 2                       0.791461                         0.247676  -1.514654
# 3                       0.237609                         0.377436  -1.387024
# 4                       0.592941                        -0.270533   0.817739
#
#    Months_Until_Card_Expiry  ...  Num_Chargebacks  \
# 0                  0.090794  ...        -0.018307
# 1                 -0.166974  ...        -0.225775
# 2                  0.207643  ...         0.247998
# 3                 -0.054952  ...        -0.108300
# 4                  0.753074  ...        -0.009431
#
#    Avg_Transaction_Amount_30Days  Num_Linked_Accounts  \
# 0                       0.277838            -0.110474
# 1                      -0.638672             0.101288
# 2                       0.771679             0.909412
# 3                       0.005274            -0.190321
# 4                       0.798278            -0.137458
#
#    Account_Login_Attempts_24h  Unusual_Purchase_Behavior_Score  \
# 0                    0.066928                         0.128539
# 1                   -0.339846                         0.167170
# 2                   -0.689281                        -0.327642
# 3                   -1.175575                         0.647376
# 4                    0.141267                        -0.206010
#
#    Cashback_Discount_Usage  ATM_Withdrawal_Amount  \
# 0                -0.189115               0.133558
# 1                 0.125895              -0.008983
# 2                -0.139097              -0.055353
# 3                -0.221929               0.062723
# 4                 0.502292               0.219422
#
#    Num_Different_Devices_Used_30Days  Transaction_Amount  Fraud_Label
# 0                          -0.021053              149.62            0
# 1                           0.014724                2.69            0
# 2                          -0.059752              378.66            0
# 3                           0.061458              123.50            0
# 4                           0.215153               69.99            0
#
# [5 rows x 30 columns]

# %%
scaler = StandardScaler()
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.2)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Weak Learner

class WeakLearner:
    def __init__(self):
# Out:
#   Cell In[9], line 5
#
#     ^
# SyntaxError: incomplete input
