# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df_time_sorted = df.sort_values(by='Date')
df_time_sorted.head()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 856  770-42-8960      B   Mandalay        Normal    Male   Food and beverages
# 567  651-88-7328      A     Yangon        Normal  Female  Fashion accessories
# 245  530-90-9855      A     Yangon        Member    Male   Home and lifestyle
# 696  182-52-7000      A     Yangon        Member  Female    Sports and travel
# 523  133-14-7229      C  Naypyitaw        Normal    Male    Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time  Payment    cogs  \
# 856       21.12         8   8.448  177.408 2019-01-01  19:31     Cash  168.96
# 567       65.74         9  29.583  621.243 2019-01-01  13:55     Cash  591.66
# 245       47.59         8  19.036  399.756 2019-01-01  14:47     Cash  380.72
# 696       27.04         4   5.408  113.568 2019-01-01  20:26  Ewallet  108.16
# 523       62.87         2   6.287  132.027 2019-01-01  11:43     Cash  125.74
#
#      gross margin percentage  gross income  Rating  Month  Year
# 856                 4.761905         8.448     6.3      1  2019
# 567                 4.761905        29.583     7.7      1  2019
# 245                 4.761905        19.036     5.7      1  2019
# 696                 4.761905         5.408     6.9      1  2019
# 523                 4.761905         6.287     5.0      1  2019

# %%
df_sorted_a = df_time_sorted[df_time_sorted['Branch']=='A']
df_sorted_a.head()
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 567  651-88-7328      A  Yangon        Normal  Female     Fashion accessories
# 245  530-90-9855      A  Yangon        Member    Male      Home and lifestyle
# 696  182-52-7000      A  Yangon        Member  Female       Sports and travel
# 829  416-17-9926      A  Yangon        Member  Female  Electronic accessories
# 17   765-26-6951      A  Yangon        Normal    Male       Sports and travel
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 567       65.74         9  29.583  621.243 2019-01-01  13:55         Cash
# 245       47.59         8  19.036  399.756 2019-01-01  14:47         Cash
# 696       27.04         4   5.408  113.568 2019-01-01  20:26      Ewallet
# 829       74.22        10  37.110  779.310 2019-01-01  14:42  Credit card
# 17        72.61         6  21.783  457.443 2019-01-01  10:39  Credit card
#
#        cogs  gross margin percentage  gross income  Rating  Month  Year
# 567  591.66                 4.761905        29.583     7.7      1  2019
# 245  380.72                 4.761905        19.036     5.7      1  2019
# 696  108.16                 4.761905         5.408     6.9      1  2019
# 829  742.20                 4.761905        37.110     4.3      1  2019
# 17   435.66                 4.761905        21.783     6.9      1  2019

# %%
df_sorted_b = df_time_sorted[df_time_sorted['Branch']=='B']
df_sorted_b.head()
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 856  770-42-8960      B  Mandalay        Normal    Male
# 970  746-04-1077      B  Mandalay        Member  Female
# 450  891-01-7034      B  Mandalay        Normal  Female
# 451  744-09-5786      B  Mandalay        Normal    Male
# 425  198-84-7132      B  Mandalay        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 856      Food and beverages       21.12         8   8.4480  177.4080
# 970      Food and beverages       84.63        10  42.3150  888.6150
# 450  Electronic accessories       74.71         6  22.4130  470.6730
# 451  Electronic accessories       22.01         6   6.6030  138.6630
# 425     Fashion accessories       40.61         9  18.2745  383.7645
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 856 2019-01-01  19:31         Cash  168.96                 4.761905
# 970 2019-01-01  11:36  Credit card  846.30                 4.761905
# 450 2019-01-01  19:07         Cash  448.26                 4.761905
# 451 2019-01-02  18:50         Cash  132.06                 4.761905
# 425 2019-01-02  13:40         Cash  365.49                 4.761905
#
#      gross income  Rating  Month  Year
# 856        8.4480     6.3      1  2019
# 970       42.3150     9.0      1  2019
# 450       22.4130     6.7      1  2019
# 451        6.6030     7.6      1  2019
# 425       18.2745     7.0      1  2019

# %%
df_sorted_c = df_time_sorted[df_time_sorted['Branch']=='C']
df_sorted_c.head()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 839  271-77-8740      C  Naypyitaw        Member  Female
# 300  446-47-6729      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 523       Health and beauty       62.87         2   6.287  132.027 2019-01-01
# 496  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
# 484       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 839       Sports and travel       29.22         6   8.766  184.086 2019-01-01
# 300     Fashion accessories       99.82         2   9.982  209.622 2019-01-02
#
#       Time      Payment    cogs  gross margin percentage  gross income  \
# 523  11:43         Cash  125.74                 4.761905         6.287
# 496  15:51         Cash  126.44                 4.761905         6.322
# 484  19:48  Credit card  369.80                 4.761905        18.490
# 839  11:40      Ewallet  175.32                 4.761905         8.766
# 300  18:09  Credit card  199.64                 4.761905         9.982
#
#      Rating  Month  Year
# 523     5.0      1  2019
# 496     8.5      1  2019
# 484     7.0      1  2019
# 839     5.0      1  2019
# 300     6.7      1  2019

# %%
month_sum_a = pd.DataFrame(df_sorted_a.groupby("Month")["Total"].sum())
month_mean_a = pd.DataFrame(df_sorted_a.groupby("Month")["Total"].mean())

month_sum_b = pd.DataFrame(df_sorted_b.groupby("Month")["Total"].sum())
month_mean_b = pd.DataFrame(df_sorted_b.groupby("Month")["Total"].mean())

month_sum_c = pd.DataFrame(df_sorted_c.groupby("Month")["Total"].sum())
month_mean_c = pd.DataFrame(df_sorted_c.groupby("Month")["Total"].mean())

# %%
from sklearn.linear_model import LinearRegression
lr_a = LinearRegression()
lr_b = LinearRegression()
lr_c = LinearRegression()

# %%
X = (df_sorted_a["Month"].unique().reshape(-1,1))
y = month_sum_a["Total"]
lr_a.fit(X,y)
y_pred = lr_a.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred)
plt.xticks(df_time_sorted["Month"].unique())
plt.show()

# %%
X = (df_sorted_b["Month"].unique().reshape(-1,1))
y = month_sum_b["Total"]
lr_b.fit(X,y)
y_pred = lr_b.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred)
plt.xticks(df_time_sorted["Month"].unique())
plt.show()

# %%
X = (df_sorted_c["Month"].unique().reshape(-1,1))
y = month_sum_c["Total"]
lr_c.fit(X,y)
y_pred = lr_c.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred)
plt.xticks(df_time_sorted["Month"].unique())
plt.show()

# %%
month_sum_total = pd.DataFrame(df_time_sorted.groupby("Month")["Total"].sum())

lr_total = LinearRegression()

X = (df_time_sorted["Month"].unique().reshape(-1,1))
y = month_sum_total["Total"]
lr_total.fit(X,y)
y_pred = lr_total.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred)
plt.xticks(df_time_sorted["Month"].unique())
plt.show()

# %%
X_forecast = np.array((61,62,63)).reshape(-1,1)
y_pred = lr_total.predict(X_forecast)
y_pred
# Out:
# array([ -94017.0665,  -97435.247 , -100853.4275])
